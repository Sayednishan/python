# %%
import pandas as pd
df1=pd.read_csv("data.csv")
df1
# Out:
# Empty DataFrame
# Columns: [1, 2, 3, 4, 5, 6, 7, 8, 9, 0, 10]
# Index: []

# %%
import pandas as pd
data=[['nishan',25],['jishan',26],['shushan',26]]
df=pd.DataFrame(data,columns=['name','age'])
df
# Out:
#       name  age
# 0   nishan   25
# 1   jishan   26
# 2  shushan   26

# %%
df.to_csv('my_data.csv')

# %%
name=df.to_excel('modified.xlsx')

# %% [markdown]
# # Data set import

# %%
df=pd.read_csv('project_data.csv')
df.head()
# Out:
#     Station  YEAR        AMT       AMiT          AR         AH       AWS  \
# 0  Dinajpur  2000  33.316667  20.000000  124.833333  81.083333  0.566667
# 1  Dinajpur  2001  33.691667  20.250000  185.500000  79.500000  0.558333
# 2  Dinajpur  2002  33.600000  20.283333  212.416667  80.666667  0.608333
# 3  Dinajpur  2003  33.133333  20.066667  171.416667  82.250000  0.608333
# 4  Dinajpur  2004  33.383333  20.025000  191.083333  81.333333  0.575000
#
#         ACC       ABS   R Area    R Pro  W Area   W Pro  GN Area  GN Pro  \
# 0  3.216667  6.183333  1452000  1328000  229857  115654      350     150
# 1  3.166667  6.616667  1396000  1285000  239835  119874      390     185
# 2  3.475000  6.725000  1364000  1254000  238917  120012      420     210
# 3  3.500000  6.158333  1402000  1410000  245328  129981      550     235
# 4  3.558333  5.891667  1497000  1390000  249835  136545      730     295
#
#    Tob Area  Tob Pro  Ba Area  Ba Pro
# 0       580      175     2772   18035
# ...

# %%
df.head(10)
# Out:
#     Station  YEAR        AMT       AMiT          AR         AH       AWS  \
# 0  Dinajpur  2000  33.316667  20.000000  124.833333  81.083333  0.566667
# 1  Dinajpur  2001  33.691667  20.250000  185.500000  79.500000  0.558333
# 2  Dinajpur  2002  33.600000  20.283333  212.416667  80.666667  0.608333
# 3  Dinajpur  2003  33.133333  20.066667  171.416667  82.250000  0.608333
# 4  Dinajpur  2004  33.383333  20.025000  191.083333  81.333333  0.575000
# 5  Dinajpur  2005  33.508333  20.391667  247.916667  80.750000  0.508333
# 6  Dinajpur  2006  34.241667  20.616667  107.083333  78.750000  0.591667
# 7  Dinajpur  2007  34.250000  20.375000  131.583333  78.916667  0.700000
# 8  Dinajpur  2008  33.391667  20.500000  147.666667  80.750000  0.633333
# 9  Dinajpur  2009  33.958333  20.533333  168.750000  78.166667  1.625000
#
#         ACC       ABS   R Area    R Pro  W Area   W Pro  GN Area  GN Pro  \
# 0  3.216667  6.183333  1452000  1328000  229857  115654      350     150
# ...

# %%
df.tail()
# Out:
#      Station  YEAR      AMT      AMiT       AR      AH       AWS       ACC  \
# 15  Dinajpur  2015  35.1210  20.22400  128.250  77.258  1.215550  3.502010
# 16  Dinajpur  2016  34.9890  20.00520  145.552  76.369  1.874150  3.521489
# 17  Dinajpur  2017  35.1281  20.06678  130.250  78.512  1.220170  3.608814
# 18  Dinajpur  2018  35.8200  20.35700  128.775  80.330  0.921520  3.374100
# 19  Dinajpur  2019  35.6212  20.92100  127.798  76.418  1.212154  3.521460
#
#          ABS   R Area    R Pro  W Area   W Pro  GN Area  GN Pro  Tob Area  \
# 15  6.201230  1839000  2213000  202015  245948     9895    5028       115
# 16  6.002100  1840000  2291000  192741  241250    10254    6062       121
# 17  6.123040  1856000  2310000  219559  251297    11358    6512       120
# 18  6.364125  1842000  2284000  201854  241874    12128    6847       112
# 19  6.214500  1855000  2285000  217852  252514    13590    7892       109
#
#     Tob Pro  Ba Area  Ba Pro
# 15       40     4703   38336
# ...

# %%
print(df.loc[15:19])
# Out:
#      Station  YEAR      AMT      AMiT       AR      AH       AWS       ACC  \
# 15  Dinajpur  2015  35.1210  20.22400  128.250  77.258  1.215550  3.502010
# 16  Dinajpur  2016  34.9890  20.00520  145.552  76.369  1.874150  3.521489
# 17  Dinajpur  2017  35.1281  20.06678  130.250  78.512  1.220170  3.608814
# 18  Dinajpur  2018  35.8200  20.35700  128.775  80.330  0.921520  3.374100
# 19  Dinajpur  2019  35.6212  20.92100  127.798  76.418  1.212154  3.521460
#
#          ABS   R Area    R Pro  W Area   W Pro  GN Area  GN Pro  Tob Area  \
# 15  6.201230  1839000  2213000  202015  245948     9895    5028       115
# 16  6.002100  1840000  2291000  192741  241250    10254    6062       121
# 17  6.123040  1856000  2310000  219559  251297    11358    6512       120
# 18  6.364125  1842000  2284000  201854  241874    12128    6847       112
# 19  6.214500  1855000  2285000  217852  252514    13590    7892       109
#
#     Tob Pro  Ba Area  Ba Pro
# 15       40     4703   38336
# ...

# %%
print(df.iloc[15:19])
# Out:
#      Station  YEAR      AMT      AMiT       AR      AH      AWS       ACC  \
# 15  Dinajpur  2015  35.1210  20.22400  128.250  77.258  1.21555  3.502010
# 16  Dinajpur  2016  34.9890  20.00520  145.552  76.369  1.87415  3.521489
# 17  Dinajpur  2017  35.1281  20.06678  130.250  78.512  1.22017  3.608814
# 18  Dinajpur  2018  35.8200  20.35700  128.775  80.330  0.92152  3.374100
#
#          ABS   R Area    R Pro  W Area   W Pro  GN Area  GN Pro  Tob Area  \
# 15  6.201230  1839000  2213000  202015  245948     9895    5028       115
# 16  6.002100  1840000  2291000  192741  241250    10254    6062       121
# 17  6.123040  1856000  2310000  219559  251297    11358    6512       120
# 18  6.364125  1842000  2284000  201854  241874    12128    6847       112
#
#     Tob Pro  Ba Area  Ba Pro
# 15       40     4703   38336
# 16       44     4712   38305
# 17       45     4785   38872
# 18       38     4871   39001

# %%
df.shape #(row,column)
# Out:
# (20, 19)

# %%
df['ABS'].count()
# Out:
# 20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Station   20 non-null     object
#  1   YEAR      20 non-null     int64
#  2   AMT       20 non-null     float64
#  3   AMiT      20 non-null     float64
#  4   AR        20 non-null     float64
#  5   AH        20 non-null     float64
#  6   AWS       20 non-null     float64
#  7   ACC       20 non-null     float64
#  8   ABS       20 non-null     float64
#  9   R Area    20 non-null     int64
#  10  R Pro     20 non-null     int64
#  11  W Area    20 non-null     int64
#  12  W Pro     20 non-null     int64
#  13  GN Area   20 non-null     int64
#  14  GN Pro    20 non-null     int64
#  15  Tob Area  20 non-null     int64
#  16  Tob Pro   20 non-null     int64
#  17  Ba Area   20 non-null     int64
#  18  Ba Pro    20 non-null     int64
# dtypes: float64(7), int64(11), object(1)
# ...

# %%
x=df[['AMiT','AWS']]
x
# Out:
#          AMiT       AWS
# 0   20.000000  0.566667
# 1   20.250000  0.558333
# 2   20.283333  0.608333
# 3   20.066667  0.608333
# 4   20.025000  0.575000
# 5   20.391667  0.508333
# 6   20.616667  0.591667
# 7   20.375000  0.700000
# 8   20.500000  0.633333
# 9   20.533333  1.625000
# 10  20.666667  1.758333
# 11  20.125000  1.616667
# 12  20.041667  1.625000
# 13  20.058333  1.741667
# 14  19.023500  0.982151
# 15  20.224000  1.215550
# 16  20.005200  1.874150
# 17  20.066780  1.220170
# 18  20.357000  0.921520
# 19  20.921000  1.212154

# %%
df.describe()
# Out:
#              YEAR        AMT       AMiT          AR         AH        AWS  \
# count    20.00000  20.000000  20.000000   20.000000  20.000000  20.000000
# mean   2009.50000  34.130987  20.226541  151.845933  79.018700   1.057118
# std       5.91608   0.803384   0.382464   34.748678   1.746085   0.493920
# min    2000.00000  33.133333  19.023500  107.083333  76.369000   0.508333
# 25%    2004.75000  33.539583  20.054167  128.643750  77.927750   0.604167
# 50%    2009.50000  33.891667  20.237000  136.875000  78.833333   0.951836
# 75%    2014.25000  34.534750  20.418750  169.416667  80.687500   1.618750
# max    2019.00000  35.820000  20.921000  247.916667  82.250000   1.874150
#
#              ACC        ABS        R Area         R Pro         W Area  \
# count  20.000000  20.000000  2.000000e+01  2.000000e+01      20.000000
# mean    3.435501   6.210990  1.690310e+06  1.924850e+06  217856.950000
# std     0.169373   0.225954  1.829105e+05  4.211587e+05   18532.399707
# ...

# %% [markdown]
# # mean er caye max value beshi hole OUTLAYER

# %%
x.to_csv('x.csv')

# %%
print(pd.read_csv('x.csv'))
# Out:
#     Unnamed: 0       AMiT       AWS
# 0            0  20.000000  0.566667
# 1            1  20.250000  0.558333
# 2            2  20.283333  0.608333
# 3            3  20.066667  0.608333
# 4            4  20.025000  0.575000
# 5            5  20.391667  0.508333
# 6            6  20.616667  0.591667
# 7            7  20.375000  0.700000
# 8            8  20.500000  0.633333
# 9            9  20.533333  1.625000
# 10          10  20.666667  1.758333
# 11          11  20.125000  1.616667
# 12          12  20.041667  1.625000
# 13          13  20.058333  1.741667
# 14          14  19.023500  0.982151
# 15          15  20.224000  1.215550
# 16          16  20.005200  1.874150
# 17          17  20.066780  1.220170
# 18          18  20.357000  0.921520
# 19          19  20.921000  1.212154

# %%
import pandas as pd
df=pd.read_csv('doc.csv')
df
# Out:
#    Unnamed: 0        Id     NAME DEPARTMENT  RESULT
# 0           0  18CHE001   NISHAN  CHEMISTRY    3.52
# 1           1  18CHE002  SAFAWAT  CHEMISTRY    4.00
# 2           2  18CHE003    RAHIM  CHEMISTRY    3.50
# 3           3  18CHE004   SHAHID  CHEMISTRY    4.00
# 4           4  18CHE005   KHALID  CHEMISTRY    3.98

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'NAME', 'DEPARTMENT', 'RESULT'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.NAME
# Out:
# 0     NISHAN
# 1    SAFAWAT
# 2      RAHIM
# 3     SHAHID
# 4     KHALID
# Name: NAME, dtype: object

# %%
df['NAME'][0:2]
# Out:
# 0     NISHAN
# 1    SAFAWAT
# Name: NAME, dtype: object

# %%
df[['NAME','RESULT']]
# Out:
#       NAME  RESULT
# 0   NISHAN    3.52
# 1  SAFAWAT    4.00
# 2    RAHIM    3.50
# 3   SHAHID    4.00
# 4   KHALID    3.98

# %%
for index,row in df.iterrows():
    print(index,row)
# Out:
# 0 Unnamed: 0            0
# Id             18CHE001
# NAME             NISHAN
# DEPARTMENT    CHEMISTRY
# RESULT             3.52
# Name: 0, dtype: object
# 1 Unnamed: 0            1
# Id             18CHE002
# NAME            SAFAWAT
# DEPARTMENT    CHEMISTRY
# RESULT              4.0
# Name: 1, dtype: object
# 2 Unnamed: 0            2
# Id             18CHE003
# NAME              RAHIM
# DEPARTMENT    CHEMISTRY
# RESULT              3.5
# Name: 2, dtype: object
# 3 Unnamed: 0            3
# Id             18CHE004
# NAME             SHAHID
# DEPARTMENT    CHEMISTRY
# RESULT              4.0
# Name: 3, dtype: object
# 4 Unnamed: 0            4
# Id             18CHE005
# NAME             KHALID
# DEPARTMENT    CHEMISTRY
# RESULT             3.98
# Name: 4, dtype: object

# %%
df.loc[df['NAME']== "grass"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Id, NAME, DEPARTMENT, RESULT]
# Index: []

# %%
df.sort_values('RESULT',ascending=False)
# Out:
#    Unnamed: 0        Id     NAME DEPARTMENT  RESULT
# 1           1  18CHE002  SAFAWAT  CHEMISTRY    4.00
# 3           3  18CHE004   SHAHID  CHEMISTRY    4.00
# 4           4  18CHE005   KHALID  CHEMISTRY    3.98
# 0           0  18CHE001   NISHAN  CHEMISTRY    3.52
# 2           2  18CHE003    RAHIM  CHEMISTRY    3.50

# %%
df.sort_values('RESULT',ascending=True)
df
# Out:
#    Unnamed: 0        Id     NAME DEPARTMENT  RESULT
# 0           0  18CHE001   NISHAN  CHEMISTRY    3.52
# 1           1  18CHE002  SAFAWAT  CHEMISTRY    4.00
# 2           2  18CHE003    RAHIM  CHEMISTRY    3.50
# 3           3  18CHE004   SHAHID  CHEMISTRY    4.00
# 4           4  18CHE005   KHALID  CHEMISTRY    3.98

# %%
df['DISTRICT']='SAVAR','SAVAR','SAVAR','SAVAR','SAVAR'
df
# Out:
#    Unnamed: 0        Id     NAME DEPARTMENT  RESULT DISTRICT
# 0           0  18CHE001   NISHAN  CHEMISTRY    3.52    SAVAR
# 1           1  18CHE002  SAFAWAT  CHEMISTRY    4.00    SAVAR
# 2           2  18CHE003    RAHIM  CHEMISTRY    3.50    SAVAR
# 3           3  18CHE004   SHAHID  CHEMISTRY    4.00    SAVAR
# 4           4  18CHE005   KHALID  CHEMISTRY    3.98    SAVAR

# %%
df=df.drop(columns=['DISTRICT'])
df
# Out:
#    Unnamed: 0        Id     NAME DEPARTMENT  RESULT
# 0           0  18CHE001   NISHAN  CHEMISTRY    3.52
# 1           1  18CHE002  SAFAWAT  CHEMISTRY    4.00
# 2           2  18CHE003    RAHIM  CHEMISTRY    3.50
# 3           3  18CHE004   SHAHID  CHEMISTRY    4.00
# 4           4  18CHE005   KHALID  CHEMISTRY    3.98

# %%
df['tot']=df.iloc[1:5].sum(axis=0)
df
# Out:
#    Unnamed: 0        Id     NAME DEPARTMENT  RESULT  tot
# 0           0  18CHE001   NISHAN  CHEMISTRY    3.52  NaN
# 1           1  18CHE002  SAFAWAT  CHEMISTRY    4.00  NaN
# 2           2  18CHE003    RAHIM  CHEMISTRY    3.50  NaN
# 3           3  18CHE004   SHAHID  CHEMISTRY    4.00  NaN
# 4           4  18CHE005   KHALID  CHEMISTRY    3.98  NaN

# %%
dfn=pd.read_csv('pokemon_data.csv')
dfn
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
dfn.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
dfn['TOTAL']=dfn.iloc[:,4:10].sum(axis=1)
new=dfn.head(5)
new.to_csv('new.csv')

# %%
dfn.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  TOTAL
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
cols=list(dfn.columns.values)
dfn=dfn[cols[0:4]+[cols[-1]]+cols[4:12]]
dfn.head(5)
# Out:
#    #                   Name Type 1  Type 2  TOTAL  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df=pd.read_csv('new.csv')
df
# Out:
#    Unnamed: 0  #                   Name Type 1  Type 2  Sp. Def  Sp. Def.1  \
# 0           0  1              Bulbasaur  Grass  Poison       65         65
# 1           1  2                Ivysaur  Grass  Poison       80         80
# 2           2  3               Venusaur  Grass  Poison      100        100
# 3           3  3  VenusaurMega Venusaur  Grass  Poison      120        120
# 4           4  4             Charmander   Fire     NaN       50         50
#
#    Sp. Def.2  Sp. Def.3  Speed  ...  Speed.3  Speed.4  Speed.5  Speed.6  \
# 0         65         65     45  ...       45       45       45       45
# 1         80         80     60  ...       60       60       60       60
# 2        100        100     80  ...       80       80       80       80
# 3        120        120     80  ...       80       80       80       80
# 4         50         50     65  ...       65       65       65       65
#
#    Speed.7  HP  Attack  Defense  Sp. Atk  TOTAL
# ...

# %%
df.loc[df['Type 1']=='Grass']
df.head(5)
# Out:
#    Unnamed: 0  #                   Name Type 1  Type 2  Sp. Def  Sp. Def.1  \
# 0           0  1              Bulbasaur  Grass  Poison       65         65
# 1           1  2                Ivysaur  Grass  Poison       80         80
# 2           2  3               Venusaur  Grass  Poison      100        100
# 3           3  3  VenusaurMega Venusaur  Grass  Poison      120        120
# 4           4  4             Charmander   Fire     NaN       50         50
#
#    Sp. Def.2  Sp. Def.3  Speed  ...  Speed.3  Speed.4  Speed.5  Speed.6  \
# 0         65         65     45  ...       45       45       45       45
# 1         80         80     60  ...       60       60       60       60
# 2        100        100     80  ...       80       80       80       80
# 3        120        120     80  ...       80       80       80       80
# 4         50         50     65  ...       65       65       65       65
#
#    Speed.7  HP  Attack  Defense  Sp. Atk  TOTAL
# ...

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#    Unnamed: 0  #                   Name Type 1  Type 2  Sp. Def  Sp. Def.1  \
# 3           3  3  VenusaurMega Venusaur  Grass  Poison      120        120
#
#    Sp. Def.2  Sp. Def.3  Speed  ...  Speed.3  Speed.4  Speed.5  Speed.6  \
# 3        120        120     80  ...       80       80       80       80
#
#    Speed.7  HP  Attack  Defense  Sp. Atk  TOTAL
# 3       80  80     100      123      122    640
#
# [1 rows x 22 columns]

# %%
import re
df.loc[df['Type 1'].str.contains('Grass|Fire',regex=True)]
df.head(10)
# Out:
#    Unnamed: 0  #                   Name Type 1  Type 2  Sp. Def  Sp. Def.1  \
# 0           0  1              Bulbasaur  Grass  Poison       65         65
# 1           1  2                Ivysaur  Grass  Poison       80         80
# 2           2  3               Venusaur  Grass  Poison      100        100
# 3           3  3  VenusaurMega Venusaur  Grass  Poison      120        120
# 4           4  4             Charmander   Fire     NaN       50         50
#
#    Sp. Def.2  Sp. Def.3  Speed  ...  Speed.3  Speed.4  Speed.5  Speed.6  \
# 0         65         65     45  ...       45       45       45       45
# 1         80         80     60  ...       60       60       60       60
# 2        100        100     80  ...       80       80       80       80
# 3        120        120     80  ...       80       80       80       80
# 4         50         50     65  ...       65       65       65       65
#
#    Speed.7  HP  Attack  Defense  Sp. Atk  TOTAL
# ...

# %%
import re
dfn.loc[dfn['Name'].str.contains('pi[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                     Name    Type 1    Type 2  Sp. Def  Sp. Def  \
# 13    10                 Caterpie       Bug       NaN       20       20
# 20    16                   Pidgey    Normal    Flying       35       35
# 21    17                Pidgeotto    Normal    Flying       50       50
# 22    18                  Pidgeot    Normal    Flying       70       70
# 23    18      PidgeotMega Pidgeot    Normal    Flying       80       80
# 30    25                  Pikachu  Electric       NaN       50       50
# 42    37                   Vulpix      Fire       NaN       65       65
# 76    70               Weepinbell     Grass    Poison       45       45
# 84    78                 Rapidash      Fire       NaN       80       80
# 136  127                   Pinsir       Bug       NaN       70       70
# 137  127        PinsirMega Pinsir       Bug    Flying       90       90
# 181  167                 Spinarak       Bug    Poison       40       40
# ...

# %%
dfn.loc[dfn['Type 1']=='Fire','Type 1']='Flamer'
dfn
# Out:
#        #                   Name   Type 1  Type 2  Sp. Def  Sp. Def  Sp. Def  \
# 0      1              Bulbasaur    Grass  Poison       65       65       65
# 1      2                Ivysaur    Grass  Poison       80       80       80
# 2      3               Venusaur    Grass  Poison      100      100      100
# 3      3  VenusaurMega Venusaur    Grass  Poison      120      120      120
# 4      4             Charmander   Flamer     NaN       50       50       50
# ..   ...                    ...      ...     ...      ...      ...      ...
# 795  719                Diancie     Rock   Fairy      150      150      150
# 796  719    DiancieMega Diancie     Rock   Fairy      110      110      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost      130      130      130
# 798  720     HoopaHoopa Unbound  Psychic    Dark      130      130      130
# 799  721              Volcanion   Flamer   Water       90       90       90
#
# ...

# %%
dfn
# Out:
#        #                   Name   Type 1  Type 2  Sp. Def  Sp. Def  Sp. Def  \
# 0      1              Bulbasaur    Grass  Poison       65       65       65
# 1      2                Ivysaur    Grass  Poison       80       80       80
# 2      3               Venusaur    Grass  Poison      100      100      100
# 3      3  VenusaurMega Venusaur    Grass  Poison      120      120      120
# 4      4             Charmander     Fire     NaN       50       50       50
# ..   ...                    ...      ...     ...      ...      ...      ...
# 795  719                Diancie     Rock   Fairy      150      150      150
# 796  719    DiancieMega Diancie     Rock   Fairy      110      110      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost      130      130      130
# 798  720     HoopaHoopa Unbound  Psychic    Dark      130      130      130
# 799  721              Volcanion     Fire   Water       90       90       90
#
# ...

# %%
dfn.loc[dfn['Type 1'].str.contains('Flamer')]
# Out:
#        #                       Name  Type 1    Type 2  Sp. Def  Sp. Def  \
# 4      4                 Charmander  Flamer       NaN       50       50
# 5      5                 Charmeleon  Flamer       NaN       65       65
# 6      6                  Charizard  Flamer    Flying       85       85
# 7      6  CharizardMega Charizard X  Flamer    Dragon       85       85
# 8      6  CharizardMega Charizard Y  Flamer    Flying      115      115
# 42    37                     Vulpix  Flamer       NaN       65       65
# 43    38                  Ninetales  Flamer       NaN      100      100
# 63    58                  Growlithe  Flamer       NaN       50       50
# 64    59                   Arcanine  Flamer       NaN       80       80
# 83    77                     Ponyta  Flamer       NaN       65       65
# 84    78                   Rapidash  Flamer       NaN       80       80
# 135  126                     Magmar  Flamer       NaN       85       85
# ...

# %%
import pandas as pd
df=pd.read_csv('dirtydata.csv')
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
new_df=df.dropna() #missind value drop
new_df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.fillna(130,inplace=True) #replace missing value
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.loc[df['Date']==130]=' \'2020/12/24\' '
df
# Out:
#    Duration          Date Pulse Maxpulse Calories
# 0        60  '2020/12/01'   110      130    409.1
# 1        60  '2020/12/02'   117      145    479.0
# 2        60  '2020/12/03'   103      135    340.0
# 3        45  '2020/12/04'   109      175    282.4
# 4        45  '2020/12/05'   117      148    406.0
# 5        60  '2020/12/06'   102      127    300.0
# 6        60  '2020/12/07'   110      136    374.0
# 7       450  '2020/12/08'   104      134    253.3
# 8        30  '2020/12/09'   109      133    195.1
# 9        60  '2020/12/10'    98      124    269.0
# 10       60  '2020/12/11'   103      147    329.3
# 11       60  '2020/12/12'   100      120    250.7
# 12       60  '2020/12/12'   100      120    250.7
# 13       60  '2020/12/13'   106      128    345.3
# 14       60  '2020/12/14'   104      132    379.3
# 15       60  '2020/12/15'    98      123    275.0
# 16       60  '2020/12/16'    98      120    215.2
# 17       60  '2020/12/17'   100      120    300.0
# ...

# %%
df=df['Calories'].fillna(130,inplace=True)
df

# %%
df=pd.read_csv('dirtydata.csv')
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df['Calories'].fillna(130,inplace=True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df['Date'].fillna(' 2020/12/22 ', inplace=True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df['Calories'].median()
# Out:
# 282.2

# %%
df2.loc[7,'Duration']=45
df2
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7         45  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
df2['Date']=pd.to_datetime(df2['Date'])
df2
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7         45 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 12        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# ...

# %%
df2=pd.read_csv('dirtydata.csv')
df2
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
x=df2['Calories'].mean()
df2['Calories'].fillna(x,inplace=True)
df2
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
df2.loc[7,'Duration']=45
df2
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7         45  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
df2=pd.read_csv('dirtydata.csv')
df2
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df2=pd.read_csv('dirtydata.csv')
df2
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
x=df2['Calories'].mean()
df2['Calories'].fillna(x,inplace=True)
df2
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
y=df2['Calories'].mode()
df2['Calories'].fillna(y,inplace=True)
df2
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df2=pd.read_csv('dirtydata.csv')
df2

# %%
df2.loc[7,'Duration']=45
df2
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7         45  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df2['Date']=pd.to_datetime(df2['Date'])
df2
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7         45 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 12        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# ...

# %%
z=df2['Calories'].median()
df2['Calories'].fillna(z,inplace=True)
df2
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7         45  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df2.loc[22,'Date']='2020-12-22'
df2
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7         45 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 12        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# ...

# %%
df2.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df2.drop_duplicates(inplace=True)
df2
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7         45 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# ...

# %%
df2.describe()
# Out:
#         Duration       Pulse    Maxpulse    Calories
# count  31.000000   31.000000   31.000000   31.000000
# mean   55.645161  103.612903  128.774194  306.421290
# std     7.931155    7.935899   13.119222   64.117245
# min    30.000000   90.000000  101.000000  195.100000
# 25%    52.500000  100.000000  120.000000  252.000000
# 50%    60.000000  103.000000  128.000000  300.000000
# 75%    60.000000  107.000000  132.500000  342.650000
# max    60.000000  130.000000  175.000000  479.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  31 non-null     int64
#  1   Date      31 non-null     datetime64[ns]
#  2   Pulse     31 non-null     int64
#  3   Maxpulse  31 non-null     int64
#  4   Calories  31 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 1.5 KB

# %%
ndf=pd.read_csv('kerala.csv')
ndf
# Out:
#     SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 0        KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 1        KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 2        KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3        KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 4        KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
# ..          ...   ...   ...   ...   ...    ...    ...     ...     ...    ...
# 110      KERALA  2011  20.5  45.7  24.1  165.2  124.2   788.5   536.8  492.7
# 111      KERALA  2012   7.4  11.0  21.0  171.1   95.3   430.3   362.6  501.6
# 112      KERALA  2013   3.9  40.1  49.9   49.3  119.3  1042.7   830.2  369.7
# 113      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8  733.9
# 114      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0  252.2
#
# ...

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  115 non-null    object
#  1   YEAR         115 non-null    int64
#  2   JAN          115 non-null    float64
#  3   FEB          115 non-null    float64
#  4   MAR          115 non-null    float64
#  5   APR          115 non-null    float64
#  6   MAY          115 non-null    float64
#  7   JUN          115 non-null    float64
#  8   JUL          115 non-null    float64
#  9   AUG          115 non-null    float64
#  10  SEP          115 non-null    float64
#  11  OCT          115 non-null    float64
#  12  NOV          115 non-null    float64
#  13  DEC          115 non-null    float64
#  14  ANNUAL       115 non-null    float64
#  15  Jan-Feb      115 non-null    float64
#  16  Mar-May      115 non-null    float64
#  17  Jun-Sep      115 non-null    float64
# ...

# %%
ndf.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   115.000000  115.000000  115.000000  115.000000  115.000000
# mean   1958.000000   12.246957   15.496522   36.814783  110.573913
# std      33.341666   15.538923   16.206572   30.324601   44.673971
# min    1901.000000    0.000000    0.000000    0.100000   13.100000
# 25%    1929.500000    2.250000    4.700000   18.100000   74.800000
# 50%    1958.000000    6.000000    8.400000   28.300000  109.800000
# 75%    1986.500000   17.750000   21.400000   50.000000  136.000000
# max    2015.000000   83.500000   79.000000  217.200000  238.000000
#
#               MAY          JUN          JUL          AUG         SEP  \
# count  115.000000   115.000000   115.000000   115.000000  115.000000
# mean   229.881739   654.302609   700.953043   421.977391  245.619130
# std    149.271697   187.642791   225.294102   159.693779  122.130976
# min     53.400000   196.800000   167.500000   178.600000   41.300000
# ...

# %%
print(ndf.duplicated())
ndf.loc[:]
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 110    False
# 111    False
# 112    False
# 113    False
# 114    False
# Length: 115, dtype: bool
#     SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 0        KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 1        KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 2        KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3        KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 4        KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
# ..          ...   ...   ...   ...   ...    ...    ...     ...     ...    ...
# 110      KERALA  2011  20.5  45.7  24.1  165.2  124.2   788.5   536.8  492.7
# 111      KERALA  2012   7.4  11.0  21.0  171.1   95.3   430.3   362.6  501.6
# 112      KERALA  2013   3.9  40.1  49.9   49.3  119.3  1042.7   830.2  369.7
# ...

# %%
columns=ndf[['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC','ANNUAL','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec']]
x=columns.describe()
print(x.to_string())
# Out:
#               JAN         FEB         MAR         APR         MAY          JUN          JUL          AUG         SEP         OCT         NOV         DEC       ANNUAL     Jan-Feb     Mar-May      Jun-Sep     Oct-Dec
# count  115.000000  115.000000  115.000000  115.000000  115.000000   115.000000   115.000000   115.000000  115.000000  115.000000  115.000000  115.000000   115.000000  115.000000  115.000000   115.000000  115.000000
# mean    12.246957   15.496522   36.814783  110.573913  229.881739   654.302609   700.953043   421.977391  245.619130  294.122609  163.560000   39.950435  2925.487826   27.739130  377.253913  2022.840870  497.636522
# std     15.538923   16.206572   30.324601   44.673971  149.271697   187.642791   225.294102   159.693779  122.130976   94.060203   83.882421   37.049051   422.112193   22.361032  151.091850   386.254397  129.860643
# ...

# %%
print(ndf)
# Out:
#     SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 0        KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 1        KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 2        KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3        KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 4        KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
# ..          ...   ...   ...   ...   ...    ...    ...     ...     ...    ...
# 110      KERALA  2011  20.5  45.7  24.1  165.2  124.2   788.5   536.8  492.7
# 111      KERALA  2012   7.4  11.0  21.0  171.1   95.3   430.3   362.6  501.6
# 112      KERALA  2013   3.9  40.1  49.9   49.3  119.3  1042.7   830.2  369.7
# 113      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8  733.9
# 114      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0  252.2
#
# ...

# %%
print(ndf.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 110    False
# 111    False
# 112    False
# 113    False
# 114    False
# Length: 115, dtype: bool

# %%
ndf.iloc[5:110]
# Out:
#     SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 5        KERALA  1906  26.7   7.4    9.9   59.4  160.8  414.9  954.2  442.8
# 6        KERALA  1907  18.8   4.8   55.7  170.8  101.4  770.9  760.4  981.5
# 7        KERALA  1908   8.0  20.8   38.2  102.9  142.6  592.6  902.2  352.9
# 8        KERALA  1909  54.1  11.8   61.3   93.8  473.2  704.7  782.3  258.0
# 9        KERALA  1910   2.7  25.7   23.3  124.5  148.8  680.0  484.1  473.8
# ..          ...   ...   ...   ...    ...    ...    ...    ...    ...    ...
# 105      KERALA  2006   8.1   0.5   90.7   65.3  521.2  482.4  804.0  432.6
# 106      KERALA  2007   0.5   5.6    7.3  138.5  192.7  705.9  966.3  489.6
# 107      KERALA  2008   0.8  30.3  217.2  108.4   81.2  469.9  505.1  349.0
# 108      KERALA  2009   3.3   1.5   62.6   69.0  191.6  438.2  924.9  269.3
# 109      KERALA  2010  18.6   1.0   31.4  138.9  190.6  667.5  629.0  356.0
#
# ...
